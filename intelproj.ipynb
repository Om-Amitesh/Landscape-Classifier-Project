jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18175.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14482.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16905.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19209.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/755.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8032.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14667.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/9.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15803.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/12762.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/56.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/12434.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2946.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/9356.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/7457.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11722.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/6626.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18811.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18147.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14305.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18114.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10851.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8104.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17341.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10354.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10224.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3626.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17688.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14049.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/5618.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/12203.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1689.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2785.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/5911.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2470.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/4034.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3378.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/5222.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2374.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8311.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11725.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/113.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8300.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/6815.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18779.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/9448.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/5613.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/5267.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/13025.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1928.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/9376.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1499.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11926.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1269.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17490.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2675.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/31.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18606.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1059.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10216.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15138.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14322.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18016.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11737.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18571.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/5694.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16387.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10430.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/7601.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/7591.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8543.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2288.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14103.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/6686.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3845.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1186.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19438.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18984.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/74.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16821.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18799.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/12556.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16072.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14633.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18595.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/13750.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/13594.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/9351.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1077.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19550.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/12360.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/6425.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8026.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11803.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3244.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/5677.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/406.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1472.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3938.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19242.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11113.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17765.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/7692.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/7454.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/13473.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/13643.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18687.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/7367.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16433.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15961.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8842.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17877.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18368.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15169.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18718.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14399.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/6132.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/5768.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3556.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/992.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14875.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1660.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/5167.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15873.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/9690.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10767.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15534.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8727.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16419.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1425.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/688.jpg

# %% [markdown]
# # Importing The Right Modules

# %%
import os
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
from torchvision.datasets import ImageFolder
import numpy as np
import matplotlib.pyplot as plt
import torchvision.transforms as tt
from torch.utils.data import DataLoader
from torchvision.datasets.utils import download_url
from torchvision.utils import make_grid
# %matplotlib inline

# %% [markdown]
# # Defining Paths and transformations
# we define paths to get our Datasets and transformations to transform them to suitable tensors

# %%
train_path = "../input/intel-image-classification/seg_train/seg_train/"
val_path ="../input/intel-image-classification/seg_test/seg_test/"
test_path = "../input/intel-image-classification/seg_pred/"
stats = ((0.485, 0.456, 0.406),(0.229, 0.224, 0.225))
train_tf = tt.Compose([  tt.Resize((150,150)), 
                         tt.RandomHorizontalFlip(),
                         tt.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1, hue=0.1),
                         tt.ToTensor(), 
                         tt.Normalize(*stats,inplace=True)])
valid_tf = tt.Compose([tt.Resize((150,150)),tt.ToTensor(), tt.Normalize(*stats)])

# %% [markdown]
# # Getting Our Data

# %%
train_ds = ImageFolder(train_path, transform = train_tf)
val_ds = ImageFolder(val_path, transform = valid_tf)

# %%
batch_size = 200

# %%
torch.manual_seed(42)
train_dl = DataLoader(train_ds,batch_size,shuffle = True, num_workers = 4, pin_memory = True)
valid_dl = DataLoader(val_ds, 300, num_workers = 4, pin_memory =True)

# %% [markdown]
# # Showing a batch
# just to check if our data is loaded correctly

# %%
def show_batch(dl):
    for img, _ in dl:
        fig, ax = plt.subplots(figsize=(14, 14))
        ax.set_xticks([]); ax.set_yticks([])
        ax.imshow(make_grid(img[:64], nrow=8).permute(1, 2, 0))
        break
show_batch(train_dl)

# %%
classes = train_dl.dataset.classes

# %% [markdown]
# # Accellerating the process(GPU time!)

# %%
def get_default_device():
    """check if gpu is available"""
    if torch.cuda.is_available():
        return torch.device("cuda")
    else:
        return torch.device("cpu")

# %%
def to_device(data, device):
    """changing the device"""
    if isinstance(data,(list,tuple)):
        return [to_device(x, device) for x in data]
    else:
        return data.to(device, non_blocking = True)

# %%
class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

# %%
device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
train_dl = DeviceDataLoader(train_dl, device)
valid_dl = DeviceDataLoader(valid_dl, device)

# %% [markdown]
# # Defining a Base Class for Image Classification

# %%
def accuracy(outputs, labels):
    _, preds = torch.max(outputs,dim = 1)
    return torch.tensor(torch.sum((preds == labels)).item()/len(preds))

# %%
class imgclassificationbase(nn.Module):
    def training_step(self, batch):
        imgs, labs = batch
        out = self(imgs)
        loss = F.cross_entropy(out,labs)
        return loss
    
    def validation_step(self, batch):
        img, labs = batch
        out = self(img)
        loss = F.cross_entropy(out,labs)
        acc = accuracy(out,labs)
        return {"val_loss":loss.detach(), "val_acc":acc}
    
    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   
        batch_accs = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      
        return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item()}
    
    def epoch_end(self, epoch, result):
        print("Epoch [{}], last_lr: {:.5f}, train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}".format(
            epoch, result['lrs'][-1], result['train_loss'], result['val_loss'], result['val_acc']))

# %% [markdown]
# # Our ResNet Model

# %%
def conv_block(inc,outc,pool = False):
    block = [
        nn.Conv2d(inc,outc,kernel_size=3, padding =1),
        nn.BatchNorm2d(outc),
        nn.ReLU(inplace=True)
    ]
    if pool:
        block.append(nn.MaxPool2d(2))
    return nn.Sequential(*block)

# %%
class ResNet(imgclassificationbase):
    def __init__(self,inc,nc):
        super().__init__()
        self.conv1 = conv_block(inc, 16)
        self.conv2 = conv_block(16, 32, pool = True)
        self.res1 = nn.Sequential(conv_block(32,32),conv_block(32,32))
        
        self.conv3 = conv_block(32,64,pool = True)
        self.conv4 = conv_block(64,128,pool = True)
        self.res2 = nn.Sequential(conv_block(128,128),conv_block(128,128))
        
        self.conv5 = conv_block(128,256,pool = True)
        self.conv6 = conv_block(256,512,pool = True)
        self.res3 = nn.Sequential(conv_block(512,512),conv_block(512,512))
        
        self.classifier = nn.Sequential(nn.MaxPool2d(4), 
                                        nn.Flatten(), 
                                        nn.Linear(512, nc))
        
    def forward(self, ip):
        out = self.conv1(ip)
        out = self.conv2(out)
        out = self.res1(out)+out
        out = self.conv3(out)
        out = self.conv4(out)
        out = self.res2(out)+out
        out = self.conv5(out)
        out = self.conv6(out)
        out = self.res3(out)+out
        out = self.classifier(out)
        return out

# %%
model= to_device(ResNet(3,6),torch.device("cuda"))
model
# Out:
# ResNet(
#   (conv1): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (res1): Sequential(
#     (0): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#   )
#   (conv3): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (res2): Sequential(
#     (0): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#   )
#   (conv5): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv6): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (res3): Sequential(
#     (0): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     (1): Flatten()
#     (2): Linear(in_features=512, out_features=6, bias=True)
#   )
# )

# %%
def try_batch(dl):
    
    for images, labels in dl:
        
        print('images.shape:', images.shape)
        out = model(images)
        print('out.shape:', out.shape)
        print('out[0]:', out[41])
        break

try_batch(train_dl)
# Out:
# images.shape: torch.Size([200, 3, 150, 150])
# out.shape: torch.Size([200, 6])
# out[0]: tensor([-0.9623, -1.3825,  0.8503, -0.3935, -6.0792, -2.5527], device='cuda:0',
#        grad_fn=<SelectBackward>)

# %% [markdown]
# # Training the Model

# %%
@torch.no_grad()
def evaluate(model, val_loader):
    model.eval()
    outputs = [model.validation_step(batch) for batch in val_loader]
    return model.validation_epoch_end(outputs)

def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

def fit_one_cycle(epochs, max_lr, model, train_loader, val_loader, 
                  weight_decay=0, grad_clip=None, opt_func=torch.optim.SGD):
    torch.cuda.empty_cache()
    history = []
    
    # Set up cutom optimizer with weight decay
    optimizer = opt_func(model.parameters(), max_lr, weight_decay=weight_decay)
    # Set up one-cycle learning rate scheduler
    sched = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr, epochs=epochs, 
                                                steps_per_epoch=len(train_loader))
    
    for epoch in range(epochs):
        # Training Phase 
        model.train()
        train_losses = []
        lrs = []
        for batch in train_loader:
            loss = model.training_step(batch)
            train_losses.append(loss)
            loss.backward()
            
            # Gradient clipping
            if grad_clip: 
                nn.utils.clip_grad_value_(model.parameters(), grad_clip)
            
            optimizer.step()
            optimizer.zero_grad()
            
            # Record & update learning rate
            lrs.append(get_lr(optimizer))
            sched.step()
        
        # Validation phase
        result = evaluate(model, val_loader)
        result['train_loss'] = torch.stack(train_losses).mean().item()
        result['lrs'] = lrs
        model.epoch_end(epoch, result)
        history.append(result)
    return history

# %%
history = [evaluate(model, valid_dl)]
history
# Out:
# [{'val_loss': 1.7931922674179077, 'val_acc': 0.15799999237060547}]

# %%
epochs = 2
lr = 1e-3
grad_clip = 1e-1
weight_decay = 1e-5
optim_func = torch.optim.AdamW

# %%
history+=fit_one_cycle(epochs,lr,model,train_dl,valid_dl,grad_clip = grad_clip, weight_decay = 1e-5, opt_func = optim_func)
# Out:
# Epoch [0], last_lr: 0.00081, train_loss: 0.8406, val_loss: 1.0398, val_acc: 0.6637
# Epoch [1], last_lr: 0.00000, train_loss: 0.4456, val_loss: 0.3943, val_acc: 0.8613

# %%
epochs = 4
lr = 1e-4 
weight_decay = 1e-6

# %%
history+=fit_one_cycle(epochs,lr,model,train_dl,valid_dl,grad_clip = grad_clip, weight_decay = 1e-5, opt_func = optim_func)
# Out:
# Epoch [0], last_lr: 0.00009, train_loss: 0.3540, val_loss: 0.4019, val_acc: 0.8613
# Epoch [1], last_lr: 0.00008, train_loss: 0.3351, val_loss: 0.3705, val_acc: 0.8670
# Epoch [2], last_lr: 0.00003, train_loss: 0.2833, val_loss: 0.3291, val_acc: 0.8823
# Epoch [3], last_lr: 0.00000, train_loss: 0.2437, val_loss: 0.3179, val_acc: 0.8883

# %% [markdown]
# # Plotting Losses and Accuracy

# %%
def plot_losses(history):
    losses = [x["val_loss"] for x in history]
    plt.plot(losses,"-x")
    plt.xlabel("epoch")
    plt.ylabel("loss")
    plt.title("loss vs epochs")
    
def plot_acc(history):
    accs = [x["val_acc"] for x in history]
    plt.plot(accs,"-x")
    plt.xlabel("epoch")
    plt .ylabel("accuracy")
    plt.title("accuracy vs epochs")

# %%
plot_losses(history)

# %%
plot_acc(history)

# %% [markdown]
# # Predicting Single Images from the test Dataset

# %%
def pred_single(img,model):
    xb = to_device(img.unsqueeze(0), device)
    yb = model(xb)
    _, preds = torch.max(yb, dim = 1)
    return preds[0].item()

# %%
test_ds = ImageFolder(test_path, transform = valid_tf)

# %%
img, _ = test_ds[0]

# %%
plt.imshow(img.permute(1,2,0))
pred = pred_single(img, model)
classes[pred]
# Out:
# 'buildings'

# %%
img, _ = test_ds[25]
pred = pred_single(img, model)
print("prediction:\t",classes[pred])
plt.imshow(img.permute(1,2,0))
# Out:
# prediction:	 buildings

# %%
img , _ = test_ds[40]
pred = pred_single(img,model)
print("prediction:\t",classes[pred])
plt.imshow(img.permute(1,2,0))
# Out:
# prediction:	 sea

# %%
img, _ = test_ds[5234]
pred = pred_single(img, model)
print("prediction:\t",classes[pred])
plt.imshow(img.permute(1,2,0))
# Out:
# prediction:	 glacier

# %%
img, _ = test_ds[7200]
pred = pred_single(img, model)
print("prediction:\t",classes[pred])
plt.imshow(img.permute(1,2,0))
# Out:
# prediction:	 sea

# %%
img, _ = test_ds[2320]
pred = pred_single(img, model)
print("prediction:\t",classes[pred])
plt.imshow(img.permute(1,2,0))
# Out:
# prediction:	 sea

# %%
projectname = "intelproj"
# !pip install jovian --upgrade --quiet

# %%
import jovian

# %%
jovian.commit(project = projectname,environment=None)
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Detected Kaggle notebook...
# [jovian] Please enter your API key ( from https://jovian.ml/ ):
# API KEY: ········
# [jovian] Uploading notebook to https://jovian.ml/om-amitesh/intelproj
